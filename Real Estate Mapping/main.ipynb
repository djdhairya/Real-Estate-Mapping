# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\Real Estate Mapping\\data\\Zillow properties.csv")

# %%
df
# Out:
#          zpid           city state     homeStatus  \
# 0    15121959  San Francisco    CA           SOLD
# 1    15077058  San Francisco    CA           SOLD
# 2    15158041  San Francisco    CA  RECENTLY_SOLD
# 3    15104519  San Francisco    CA  RECENTLY_SOLD
# 4    15113307  San Francisco    CA           SOLD
# 5    15108284  San Francisco    CA  RECENTLY_SOLD
# 6   337888164  San Francisco    CA           SOLD
# 7   332858282  San Francisco    CA  RECENTLY_SOLD
# 8    15130114  San Francisco    CA           SOLD
# 9    15076848  San Francisco    CA           SOLD
# 10   15088848  San Francisco    CA           SOLD
# 11   15180687  San Francisco    CA  RECENTLY_SOLD
# 12   80735167  San Francisco    CA           SOLD
# 13   15063579  San Francisco    CA           SOLD
# 14  332854022  San Francisco    CA  RECENTLY_SOLD
# 15  332859868  San Francisco    CA           SOLD
# 16  335653827  San Francisco    CA  RECENTLY_SOLD
# 17  335654154  San Francisco    CA  RECENTLY_SOLD
# ...

# %%
list(df.columns)
# Out:
# ['zpid',
#  'city',
#  'state',
#  'homeStatus',
#  'address',
#  'isListingClaimedByCurrentSignedInUser',
#  'isCurrentSignedInAgentResponsible',
#  'bedrooms',
#  'bathrooms',
#  'price',
#  'yearBuilt',
#  'streetAddress',
#  'zipcode',
#  'isCurrentSignedInUserVerifiedOwner',
#  'isVerifiedClaimedByCurrentSignedInUser',
#  'listingDataSource',
#  'longitude',
#  'latitude',
#  'hasBadGeocode',
#  'streetViewMetadataUrlMediaWallLatLong',
#  'streetViewMetadataUrlMediaWallAddress',
#  'streetViewServiceUrl',
#  'livingArea',
#  'homeType',
#  'lotSize',
#  'lotAreaValue',
#  'lotAreaUnits',
#  'livingAreaValue',
#  'livingAreaUnitsShort',
#  'isUndisclosedAddress',
#  'zestimate',
#  'rentZestimate',
#  'currency',
#  'hideZestimate',
#  'dateSoldString',
#  'taxAssessedValue',
#  'taxAssessedYear',
#  'country',
#  'propertyTaxRate',
#  'photoCount',
#  'isPremierBuilder',
#  'isZillowOwned',
#  'ssid',
#  'hdpUrl',
#  'tourViewCount',
#  'hasPublicVideo',
#  'lastSoldPrice',
# ...

# %%
df.describe()
# Out:
#                zpid   bedrooms  bathrooms         price    yearBuilt  \
# count  3.000000e+01  30.000000  30.000000  3.000000e+01    28.000000
# mean   9.930281e+07   2.233333   1.600000  1.333876e+06  1955.500000
# std    1.346825e+08   0.773854   0.855006  7.347398e+05    31.332742
# min    1.506358e+07   1.000000   0.000000  4.617770e+05  1890.000000
# 25%    1.510853e+07   2.000000   1.000000  9.625000e+05  1941.000000
# 50%    1.515826e+07   2.000000   1.000000  1.115000e+06  1944.500000
# 75%    1.162234e+08   3.000000   2.000000  1.548750e+06  1977.500000
# max    3.378882e+08   3.000000   4.000000  4.525000e+06  2020.000000
#
#             zipcode   longitude   latitude   livingArea        lotSize  ...  \
# count     30.000000   30.000000  30.000000    30.000000      29.000000  ...
# mean   94117.633333 -122.446685  37.762060  1307.200000   14313.793103  ...
# std        8.197911    0.037972   0.021451   694.158106   27222.674510  ...
# ...

# %%
df.isnull()
# Out:
#      zpid   city  state  homeStatus  address  \
# 0   False  False  False       False    False
# 1   False  False  False       False    False
# 2   False  False  False       False    False
# 3   False  False  False       False    False
# 4   False  False  False       False    False
# 5   False  False  False       False    False
# 6   False  False  False       False    False
# 7   False  False  False       False    False
# 8   False  False  False       False    False
# 9   False  False  False       False    False
# 10  False  False  False       False    False
# 11  False  False  False       False    False
# 12  False  False  False       False    False
# 13  False  False  False       False    False
# 14  False  False  False       False    False
# 15  False  False  False       False    False
# 16  False  False  False       False    False
# 17  False  False  False       False    False
# 18  False  False  False       False    False
# 19  False  False  False       False    False
# ...

# %%
df.dtypes
# Out:
# zpid                    int64
# city                   object
# state                  object
# homeStatus             object
# address                object
#                        ...
# unit_number           float64
# unit_amenities        float64
# open_house_details    float64
# community_details      object
# mls_id                 object
# Length: 118, dtype: object
